# %%
import pandas as pd
import os

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("shrutimechlearn/churn-modelling")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\smc\.cache\kagglehub\datasets\shrutimechlearn\churn-modelling\versions\1

# %%
file=os.listdir(path)
file
# Out:
# ['Churn_Modelling.csv']

# %%
df=pd.read_csv(os.path.join(path ,'Churn_Modelling.csv'))

# %%
df.head(3)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1

# %%
cols= ['RowNumber'	,'CustomerId',	'Surname' ,'Geography'	,'Gender']

# %%
df.drop(cols , axis=1 , inplace=True)

# %%
df.head(3)
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
#
#    IsActiveMember  EstimatedSalary  Exited
# 0               1        101348.88       1
# 1               1        112542.58       0
# 2               0        113931.57       1

# %%
df.shape
# Out:
# (10000, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CreditScore      10000 non-null  int64
#  1   Age              10000 non-null  int64
#  2   Tenure           10000 non-null  int64
#  3   Balance          10000 non-null  float64
#  4   NumOfProducts    10000 non-null  int64
#  5   HasCrCard        10000 non-null  int64
#  6   IsActiveMember   10000 non-null  int64
#  7   EstimatedSalary  10000 non-null  float64
#  8   Exited           10000 non-null  int64
# dtypes: float64(2), int64(7)
# memory usage: 703.3 KB

# %%
x=df.iloc[:,:-1]

# %%
x
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary
# 0                  1        101348.88
# 1                  1        112542.58
# 2                  0        113931.57
# 3                  0         93826.63
# 4                  1         79084.10
# ...              ...              ...
# 9995               0         96270.64
# 9996               1        101699.77
# 9997               1         42085.58
# 9998               0         92888.52
# 9999               0         38190.78
#
# [10000 rows x 8 columns]

# %%
y=df['Exited']

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss= StandardScaler()
ss.fit_transform(x)
# Out:
# array([[-0.32622142,  0.29351742, -1.04175968, ...,  0.64609167,
#          0.97024255,  0.02188649],
#        [-0.44003595,  0.19816383, -1.38753759, ..., -1.54776799,
#          0.97024255,  0.21653375],
#        [-1.53679418,  0.29351742,  1.03290776, ...,  0.64609167,
#         -1.03067011,  0.2406869 ],
#        ...,
#        [ 0.60498839, -0.27860412,  0.68712986, ..., -1.54776799,
#          0.97024255, -1.00864308],
#        [ 1.25683526,  0.29351742, -0.69598177, ...,  0.64609167,
#         -1.03067011, -0.12523071],
#        [ 1.46377078, -1.04143285, -0.35020386, ...,  0.64609167,
#         -1.03067011, -1.07636976]])

# %%
x=pd.DataFrame(ss.fit_transform(x) , columns=x.columns )

# %%
x
# Out:
#       CreditScore       Age    Tenure   Balance  NumOfProducts  HasCrCard  \
# 0       -0.326221  0.293517 -1.041760 -1.225848      -0.911583   0.646092
# 1       -0.440036  0.198164 -1.387538  0.117350      -0.911583  -1.547768
# 2       -1.536794  0.293517  1.032908  1.333053       2.527057   0.646092
# 3        0.501521  0.007457 -1.387538 -1.225848       0.807737  -1.547768
# 4        2.063884  0.388871 -1.041760  0.785728      -0.911583   0.646092
# ...           ...       ...       ...       ...            ...        ...
# 9995     1.246488  0.007457 -0.004426 -1.225848       0.807737   0.646092
# 9996    -1.391939 -0.373958  1.724464 -0.306379      -0.911583   0.646092
# 9997     0.604988 -0.278604  0.687130 -1.225848      -0.911583  -1.547768
# 9998     1.256835  0.293517 -0.695982 -0.022608       0.807737   0.646092
# 9999     1.463771 -1.041433 -0.350204  0.859965      -0.911583   0.646092
#
#       IsActiveMember  EstimatedSalary
# 0           0.970243         0.021886
# 1           0.970243         0.216534
# 2          -1.030670         0.240687
# 3          -1.030670        -0.108918
# 4           0.970243        -0.365276
# ...              ...              ...
# 9995       -1.030670        -0.066419
# 9996        0.970243         0.027988
# 9997        0.970243        -1.008643
# 9998       -1.030670        -0.125231
# 9999       -1.030670        -1.076370
#
# [10000 rows x 8 columns]

# %%
x.shape
# Out:
# (10000, 8)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test , y_train , y_test = train_test_split(x , y , test_size=0.2, random_state=10)

# %%
x_test
# Out:
#       CreditScore       Age    Tenure   Balance  NumOfProducts  HasCrCard  \
# 937      2.063884  0.484225 -0.004426  0.835324      -0.911583  -1.547768
# 9355     0.915392  0.102810  1.032908 -1.225848      -0.911583   0.646092
# 2293     0.398053  0.579578 -1.733315 -0.299734      -0.911583   0.646092
# 192     -1.774770  0.102810 -1.387538 -1.225848       0.807737  -1.547768
# 8675     0.656722  1.437761  0.687130  0.795384      -0.911583   0.646092
# ...           ...       ...       ...       ...            ...        ...
# 5624    -0.346915  0.579578 -1.387538 -1.225848      -0.911583   0.646092
# 6005    -0.150326 -1.422847  1.378686 -1.225848       0.807737  -1.547768
# 987     -0.843560 -0.469311 -1.733315  1.207697      -0.911583   0.646092
# 6152    -1.474714  2.391296 -1.041760 -1.225848      -0.911583   0.646092
# 2092     0.046263 -0.087897 -0.695982  2.795323       2.527057  -1.547768
#
#       IsActiveMember  EstimatedSalary
# 937         0.970243         1.234723
# 9355       -1.030670         1.164024
# 2293       -1.030670         1.699145
# 192        -1.030670         0.259204
# 8675       -1.030670         0.220617
# ...              ...              ...
# 5624       -1.030670         0.751341
# 6005        0.970243        -1.065242
# 987        -1.030670         0.038422
# 6152        0.970243        -1.634803
# 2092        0.970243        -0.331021
#
# [2000 rows x 8 columns]

# %% [markdown]
# ## Overfitting Early Stopping and Batch Normalization

# %%
import tensorflow
from keras.layers import Dense, BatchNormalization
from keras.regularizers import L2
from keras.models import Sequential
from keras.callbacks import EarlyStopping

# %%
ann=Sequential()

# %%
ann.add(Dense(6 , input_dim=8 , activation='relu', kernel_regularizer=L2(l2=0.01)))
ann.add(BatchNormalization())
ann.add(Dense(4, activation='relu', kernel_regularizer=L2(l2=0.01)))
ann.add(BatchNormalization())
ann.add(Dense(2 , activation='relu', kernel_regularizer=L2(l2=0.01)))
ann.add(BatchNormalization())
ann.add(Dense(1 ,activation='sigmoid'))
# Out:
# C:\Users\smc\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
ann.compile(optimizer='adam' , loss='binary_crossentropy' , metrics=['accuracy'])

# %%
ann.fit(x_train , y_train , batch_size=100 , epochs=50 , validation_data=(x_test , y_test), callbacks=EarlyStopping())
# Out:
# Epoch 1/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - accuracy: 0.5399 - loss: 0.9371 - val_accuracy: 0.6315 - val_loss: 0.7987
# Epoch 2/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6084 - loss: 0.8067 - val_accuracy: 0.7605 - val_loss: 0.7163
# Epoch 3/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7003 - loss: 0.7062 - val_accuracy: 0.7790 - val_loss: 0.6665
# Epoch 4/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7570 - loss: 0.6536 - val_accuracy: 0.7870 - val_loss: 0.6300
# Epoch 5/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7895 - loss: 0.6133 - val_accuracy: 0.7890 - val_loss: 0.6018
# Epoch 6/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8055 - loss: 0.5747 - val_accuracy: 0.7890 - val_loss: 0.5792
# Epoch 7/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8041 - loss: 0.5501 - val_accuracy: 0.7905 - val_loss: 0.5541
# Epoch 8/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8013 - loss: 0.5255 - val_accuracy: 0.7940 - val_loss: 0.5223
# Epoch 9/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8026 - loss: 0.4932 - val_accuracy: 0.7990 - val_loss: 0.4958
# Epoch 10/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7946 - loss: 0.4828 - val_accuracy: 0.7980 - val_loss: 0.4778
# Epoch 11/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8157 - loss: 0.4529 - val_accuracy: 0.8050 - val_loss: 0.4636
# Epoch 12/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8235 - loss: 0.4331 - val_accuracy: 0.8125 - val_loss: 0.4513
# Epoch 13/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8290 - loss: 0.4226 - val_accuracy: 0.8235 - val_loss: 0.4319
# Epoch 14/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8450 - loss: 0.4013 - val_accuracy: 0.8350 - val_loss: 0.4190
# Epoch 15/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8510 - loss: 0.3926 - val_accuracy: 0.8425 - val_loss: 0.4050
# Epoch 16/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8501 - loss: 0.3918 - val_accuracy: 0.8445 - val_loss: 0.4007
# Epoch 17/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8457 - loss: 0.3890 - val_accuracy: 0.8505 - val_loss: 0.3923
# Epoch 18/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8507 - loss: 0.3743 - val_accuracy: 0.8505 - val_loss: 0.3902
# Epoch 19/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8444 - loss: 0.3851 - val_accuracy: 0.8485 - val_loss: 0.3882
# Epoch 20/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8562 - loss: 0.3685 - val_accuracy: 0.8500 - val_loss: 0.3876
# Epoch 21/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8529 - loss: 0.3659 - val_accuracy: 0.8505 - val_loss: 0.3845
# Epoch 22/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8557 - loss: 0.3659 - val_accuracy: 0.8480 - val_loss: 0.3822
# Epoch 23/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8519 - loss: 0.3711 - val_accuracy: 0.8450 - val_loss: 0.3871

# %%
train_acc=ann.history.history['accuracy']
# training accuracy after validation we got testing too
test_acc=ann.history.history['val_accuracy']

# %%
len(test_acc)
# Out:
# 23

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([i for i in range(1,24)], train_acc)
plt.plot([i for i in range(1,24)], test_acc, c='red')
plt.show()

# %%
pred=ann.predict(x_test)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step

# %%
prd_data= []
for i in pred:
    if i[0]>0.5:
        prd_data.append(1)
    else:
        prd_data.append(0)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test , prd_data)*100
# Out:
# 84.15

# %%
pred1=ann.predict(x_train)
# Out:
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
prd_data1= []
for i in pred1:
    if i[0]>0.5:
        prd_data1.append(1)
    else:
        prd_data1.append(0)

# %%
accuracy_score(y_train , prd_data1)*100
# Out:
# 84.82499999999999

# %%
import matplotlib.pyplot as plt

# %%
ann.history.history
# training accuracy after validation we got testing too
# Out:
# {'accuracy': [0.3499999940395355,
#   0.4793750047683716,
#   0.6676250100135803,
#   0.765749990940094,
#   0.7954999804496765,
#   0.8081250190734863,
#   0.8158749938011169,
#   0.8192499876022339,
#   0.8198750019073486,
#   0.8212500214576721,
#   0.8198750019073486,
#   0.8242499828338623,
#   0.8358749747276306,
#   0.843874990940094,
#   0.8454999923706055,
#   0.8492500185966492,
#   0.8522499799728394],
#  'loss': [0.9356321096420288,
#   0.8253013491630554,
#   0.7530879974365234,
#   0.6951072812080383,
#   0.6436423063278198,
#   0.5984289646148682,
#   0.5546424388885498,
#   0.5111700892448425,
#   0.4786860942840576,
#   0.4546448290348053,
#   0.43785038590431213,
#   0.4292908012866974,
#   0.41936036944389343,
#   0.40803131461143494,
#   0.40211495757102966,
#   0.3965680003166199,
#   0.3899247348308563],
#  'val_accuracy': [0.5414999723434448,
#   0.7555000185966492,
#   0.7925000190734863,
#   0.7889999747276306,
#   0.7889999747276306,
#   0.7944999933242798,
#   0.7979999780654907,
#   0.8040000200271606,
#   0.8100000023841858,
#   0.809499979019165,
#   0.8119999766349792,
#   0.8119999766349792,
#   0.8335000276565552,
#   0.8395000100135803,
#   0.840499997138977,
#   0.843500018119812,
#   0.8414999842643738],
#  'val_loss': [0.8233028054237366,
#   0.7700515389442444,
#   0.7127070426940918,
#   0.660992443561554,
#   0.6156293749809265,
#   0.5743218064308167,
#   0.5344861745834351,
#   0.5012251734733582,
#   0.4758783280849457,
#   0.46306100487709045,
#   0.44511374831199646,
#   0.4336315393447876,
#   0.4202250838279724,
#   0.41487589478492737,
#   0.41021090745925903,
#   0.4052501618862152,
#   0.4103473424911499]}
